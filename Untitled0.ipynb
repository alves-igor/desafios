# %% [markdown]
# Importa arquivo excel (LOAD)

# %%
import pandas as pd

excel_data_df = pd.read_excel('SalesReport.xlsx',sheet_name='data',skiprows=[0,1,2,3], header =0)
df = excel_data_df.astype({'CustomerKey':'int'})

user_ids = excel_data_df['CustomerKey'].tolist()
print(user_ids)
unique_user_ids = user_ids
# Out:
# [213, 213, 213, 213, 213, 213, 213, 213, 213, 213, 213, 213, 213, 411, 159, 159, 159, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 519, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 87, 141, 141, 141, 141, 141, 141, 141, 141, 141, 141, 141, 141, 141, 141, 141, 141, 141, 141, 141, 141, 357, 339, 321, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 393, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 688, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 573, 
# ...

# %% [markdown]
# Transform

# %%
# chama lib da open AI
# !pip install openai


## seta variavel da API

# Substitua o texto TODO por sua API Key da OpenAI, ela será salva como uma variável de ambiente.
openai_api_key = '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'

import openai

openai.api_key = openai_api_key

def generate_ai_news(user):
  completion = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
      {
          "role": "system",
          "content": "Você é um vendedor de produtos de academia."
      },
      {
          "role": "user",
          "content": f"Crie uma mensagem para {excel_data_df['Customer']} sobre quais produtos ele deve vender em sua loja"
      }
    ]
  )
  return completion.choices[0].message.content.strip('\"')

# %% [markdown]
# LOAD

# %%
for user in user_ids:
  news = generate_ai_news(user)
  print(news)
  user['news'].append({
      "description": news
  })
# Out:
# Olá, clientes da Primal Fitness!
#
# Como vendedor de produtos de academia, estou aqui para apresentar a vocês algumas sugestões de produtos que podem ser ótimas opções para a sua loja. Vamos lá:
#
# 1. Equipamentos de musculação: Ofereça uma variedade de máquinas e aparelhos de musculação, como esteiras, elípticos, bicicletas ergométricas, bancos, barras e pesos. Esses equipamentos são essenciais para quem busca fortalecer e tonificar os músculos.
#
# 2. Acessórios para treino: Enfatize a importância dos acessórios durante os treinos, como luvas, cintos de musculação, faixas de resistência, bolas de exercício, tapetes de yoga e rolos de espuma. Esses itens auxiliam na melhora da postura, prevenção de lesões e aumento do desempenho.
#
# ...

# %%
excel_data_df.insert(12,"News",generate_ai_news)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-e8df2d04ef5c> in <cell line: 1>()
# ----> 1 excel_data_df.insert(12,"News",generate_ai_news)
#       2
#       3 print (excel_data_df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4815         if not allow_duplicates and column in self.columns:
#    4816             # Should this be a different kind of error??
# -> 4817             raise ValueError(f"cannot insert {column}, already exists")
#    4818         if not isinstance(loc, int):
#    4819             raise TypeError("loc must be int")
#
# ValueError: cannot insert News, already exists

# %%
print (excel_data_df)
file_name = 'MarksData.xlsx'
excel_data_df.to_excel(file_name)
# Out:
#       OrderDate    DueDate   ShipDate SalesOrderNumber  CustomerKey  \
# 0    2013-01-28 2013-02-09 2013-02-04          SO51710          213
# 1    2013-01-28 2013-02-09 2013-02-04          SO51710          213
# 2    2013-01-28 2013-02-09 2013-02-04          SO51710          213
# 3    2013-01-28 2013-02-09 2013-02-04          SO51710          213
# 4    2013-01-28 2013-02-09 2013-02-04          SO51710          213
# ...         ...        ...        ...              ...          ...
# 1635 2013-11-29 2013-12-11 2013-12-06          SO71945          267
# 1636 2013-11-29 2013-12-11 2013-12-06          SO71945          267
# 1637 2013-11-29 2013-12-11 2013-12-06          SO71945          267
# 1638 2013-11-29 2013-12-11 2013-12-06          SO71945          267
# 1639 2013-11-29 2013-12-11 2013-12-06          SO71945          267
#
#             Customer      BusinessType                           CityName  \
# 0     Primal Fitness               Gym             Santos, São Paulo (SP)
# ...
